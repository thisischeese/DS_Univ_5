# %%
import selenium
from selenium import webdriver


from bs4 import BeautifulSoup
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import time

# %%
mangoData=pd.DataFrame(columns=["title","location","estimation","viewCount","reviewCount"])
# Out:
# Collecting selenium
#   Downloading selenium-4.9.1-py3-none-any.whl (6.6 MB)
#      ---------------------------------------- 6.6/6.6 MB 52.3 MB/s eta 0:00:00
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.10.2-py3-none-any.whl (17 kB)
# Collecting trio~=0.17
#   Downloading trio-0.22.0-py3-none-any.whl (384 kB)
#      ---------------------------------------- 384.9/384.9 kB ? eta 0:00:00
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\users\user\anaconda3\lib\site-packages (from selenium) (1.26.14)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\user\anaconda3\lib\site-packages (from selenium) (2022.12.7)
# Collecting exceptiongroup>=1.0.0rc9
#   Downloading exceptiongroup-1.1.1-py3-none-any.whl (14 kB)
# Collecting outcome
#   Downloading outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: sniffio in c:\users\user\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\user\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: idna in c:\users\user\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: sortedcontainers in c:\users\user\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\user\anaconda3\lib\site-packages (from trio~=0.17->selenium) (22.1.0)
# Collecting async-generator>=1.9
#   Downloading async_generator-1.10-py3-none-any.whl (18 kB)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\user\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\user\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Collecting h11<1,>=0.9.0
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ---------------------------------------- 58.3/58.3 kB 3.0 MB/s eta 0:00:00
# Installing collected packages: outcome, h11, exceptiongroup, async-generator, wsproto, trio, trio-websocket, selenium
# Successfully installed async-generator-1.10 exceptiongroup-1.1.1 h11-0.14.0 outcome-1.2.0 selenium-4.9.1 trio-0.22.0 trio-websocket-0.10.2 wsproto-1.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
#path= r"C:\Users\cxz01\OneDrive\바탕 화면\soongsil university\데이터사이언스\팀프로젝트\DS_Univ_5\web_crawling\chromedriver_win32\chromedriver.exe"
path= r"..\chromedriver_win32\chromedriver.exe"
browser = webdriver.Chrome(path)

#원본 지역들
#areaList = ["가로수길","강남역","강동구","개포","수서","일원","관악구","교대","서초","구로구","금천구","논현동","대치동","도곡동","동작","사당","등촌","강서","목동","양천","방배","반포","잠원","방이동","삼성동","서래마을","송파",'가락','신사','압구정','신첨','잠실','양재동','여의도','역삼','선릉','영등포구','청담동','건대','군자','광진','광화문','노원구','대학로','혜화','동대문구','동부이촌동','마포','공덕','명동','남산','삼청','인사','상암','성산','서대문구','성북구','수유','도봉','강북','시청','남대문','신촌','이대','연남동','왕십리','성동','용산','숙대','은평구','이태원','한남동','종로','중구','중랑구','합정','망원','홍대']
areaList = ["송파",'가락','신사','압구정','신첨','잠실','양재동','여의도','역삼','선릉','영등포구','청담동','건대','군자','광진','광화문','노원구','대학로','혜화','동대문구','동부이촌동','마포','공덕','명동','남산','삼청','인사','상암','성산','서대문구','성북구','수유','도봉','강북','시청','남대문','신촌','이대','연남동','왕십리','성동','용산','숙대','은평구','이태원','한남동','종로','중구','중랑구','합정','망원','홍대']

breakSign = False

#검색 총 page 개수: 50
for area in areaList:
    print(area)
    for page in range(1,51):
        print(mangoData)
        if breakSign:
            breakSign = False
            break
        mangoplateURL=f"https://www.mangoplate.com/search/{area}?keyword={area}&page={page}"
        browser.get(mangoplateURL)
        time.sleep(2)
        pageSource = BeautifulSoup(browser.page_source)
        infoList=pageSource.find_all("div", attrs = {"class":"info"})
        
        for info in infoList[0:20]:
            title = info.find("h2", attrs = {"class" : "title"}).get_text()
            detailURL = info.find("a")["href"]
            try:
                estimation = info.find("strong", attrs = {"class" : "point search_point"}).get_text()
            except:
                estimation = info.find("strong", attrs = {"class" : "point search_point expected"}).get_text()
            viewCount = info.find("span", attrs = {"class" : "view_count"}).get_text()
            reviewCount = info.find("span", attrs = {"class" : "review_count"}).get_text()

            title = title.strip()
            detailURL = "https://www.mangoplate.com" + detailURL
            try:
                estimation = float(estimation)
            except:
                breakSign = True
                break
            viewCount = float("".join(viewCount.split(",")))
            reviewCount = float("".join(reviewCount.split(",")))

            browser.get(detailURL)
            time.sleep(1)
            pageSource = BeautifulSoup(browser.page_source)
            
            # table_rows를 정의합니다
            table_rows = pageSource.find_all('tr')

            foodType = None
            price = None
            runTime = None
            location = None
            
            # 모든 행을 순회합니다
            for row in table_rows:
                ths = row.find_all('th')
                tds = row.find_all('td')

                for i, th in enumerate(ths):
                    if "음식 종류" in th.text:
                        foodType = tds[i].text.strip()   # 해당하는 td의 텍스트를 추출합니다
                    if "가격대" in th.text:
                        price = tds[i].text.strip() # 해당하는 td의 텍스트를 추출합니다
                    if "영업시간" in th.text:
                        runTime = tds[i].text.strip() # 해당하는 td의 텍스트를 추출합니다                
            try:
                location = pageSource.find("span", attrs = {"class" : "Restaurant__InfoAddress--Text"}).get_text()
            except:
                continue
            
            newData = {"title" : [title], "location" : [location], "estimation" : [estimation], "viewCount": [viewCount], "reviewCount" : [reviewCount], "foodType" : [foodType], "price" : [price], "runTime" : [runTime]}
            newData = pd.DataFrame(newData)
            mangoData = pd.concat((mangoData, newData)).reset_index(drop = True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7032\441312745.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome(path)
# 송파
#                                                  title  \
# 0                                                  미라이
# 1                                                 상진식감
# 2     패티앤베지스\n                                    (신사)
# 3                                                  삐아프
# 4                                            와라야키 쿠이신보
# ...                                                ...
# 4034                                             부일갈매기
# 4035    팀호완\n                                    (잠실점)
# 4036                                           알라딘의양고기
# 4037  브럭시\n                                    (롯데월드몰)
# 4038                                             라이언하트
#
#                            location  estimation  viewCount  reviewCount  \
# 0        서울시 강남구 신사동 557-25 끌레르빌 1F         4.8   526248.0        131.0
# 1             서울시 강남구 신사동 518-15 B1         4.8    37905.0         48.0
# 2              서울시 강남구 신사동 525-2 1F         4.7    63134.0         91.0
# 3              서울시 강남구 신사동 525-9 1F         4.7   173210.0         86.0
# 4              서울시 강남구 신사동 539 대화빌딩         4.6   463574.0        133.0
# ...                             ...         ...        ...          ...
# 4034             서울시 송파구 잠실동 242-22         4.1    45263.0         32.0
# 4035  서울시 송파구 잠실동 40-1 롯데백화점 잠실점 2F         4.1    42857.0         38.0
# 4036         서울시 송파구 잠실동 187-15 정빌딩         4.1    33048.0         21.0
# 4037        서울시 송파구 신천동 29 롯데월드몰 B1         4.1    83475.0         64.0
# 4038        서울시 송파구 송파동 31-2 B 104호         4.1    39853.0         18.0
#
#              foodType    price                                runTime
# 0      이자카야 / 오뎅 / 꼬치  3만원-4만원                          18:00 - 01:00
# 1               까스 요리   만원-2만원                          11:30 - 21:00
# 2     브런치 / 버거 / 샌드위치   만원-2만원                          11:30 - 22:00
# 3            카페 / 디저트   만원-2만원                          12:30 - 19:30
# 4      이자카야 / 오뎅 / 꼬치  2만원-3만원  월-목: 17:30 - 01:00 금-토: 17:30 - 02:00
# ...               ...      ...                                    ...
# 4034            고기 요리   만원-2만원                          17:00 - 23:00
# 4035          딤섬 / 만두   만원-2만원                          11:30 - 21:30
# 4036            기타 중식  2만원-3만원    월-토: 17:00 - 01:00 일: 17:00 - 24:00
# 4037  브런치 / 버거 / 샌드위치    만원 미만                          10:30 - 22:00
# 4038         칵테일 / 와인  2만원-3만원                          18:00 - 01:00
#
# [4039 rows x 8 columns]
#                                                  title  \
# 0                                                  미라이
# 1                                                 상진식감
# 2     패티앤베지스\n                                    (신사)
# 3                                                  삐아프
# 4                                            와라야키 쿠이신보
# ...                                                ...
# 4054                                          콰이어트 크림티
# 4055                                           라미아파밀리아
# 4056                                               더마칸
# 4057                                                그곁
# 4058                                          선호커피로스터스
#
#                         location  estimation  viewCount  reviewCount  \
# 0     서울시 강남구 신사동 557-25 끌레르빌 1F         4.8   526248.0        131.0
# 1          서울시 강남구 신사동 518-15 B1         4.8    37905.0         48.0
# 2           서울시 강남구 신사동 525-2 1F         4.7    63134.0         91.0
# 3           서울시 강남구 신사동 525-9 1F         4.7   173210.0         86.0
# 4           서울시 강남구 신사동 539 대화빌딩         4.6   463574.0        133.0
# ...                          ...         ...        ...          ...
# 4054             서울시 송파구 삼전동 2-4         4.4    64334.0         60.0
# 4055        서울시 송파구 석촌동 157-1 2F         4.4    64646.0         24.0
# 4056         서울시 송파구 방이동 98-6 1F         4.4    51980.0         33.0
# 4057         서울시 송파구 송파동 51-9 1F         4.4    27931.0         16.0
# 4058        서울시 송파구 송파동 103-9 1F         4.4     6014.0         11.0
#
#              foodType    price                                runTime
# 0      이자카야 / 오뎅 / 꼬치  3만원-4만원                          18:00 - 01:00
# 1               까스 요리   만원-2만원                          11:30 - 21:00
# 2     브런치 / 버거 / 샌드위치   만원-2만원                          11:30 - 22:00
# 3            카페 / 디저트   만원-2만원                          12:30 - 19:30
# 4      이자카야 / 오뎅 / 꼬치  2만원-3만원  월-목: 17:30 - 01:00 금-토: 17:30 - 02:00
# ...               ...      ...                                    ...
# 4054         카페 / 디저트    만원 미만  수-금: 12:00 - 20:00 토-일: 12:00 - 21:00
# 4055             이탈리안  3만원-4만원                          11:00 - 22:00
# 4056       다국적 아시아 음식   만원-2만원    월: 17:30 - 22:00 화-토: 11:30 - 22:00
# 4057            일반 주점  2만원-3만원                          18:00 - 01:00
# 4058         카페 / 디저트    만원 미만  화-금: 07:00 - 16:00 토-일: 11:00 - 18:00
#
# [4059 rows x 8 columns]
#                                                   title  \
# 0                                                   미라이
# 1                                                  상진식감
# 2      패티앤베지스\n                                    (신사)
# 3                                                   삐아프
# 4                                             와라야키 쿠이신보
# ...                                                 ...
# 4074                                               파오파오
# 4075    모터시티\n                                    (잠실점)
# 4076                                             신양로스터스
# 4077                                                송계옥
# 4078  하얼빈양꼬치\n                                    (잠...
#
#                         location  estimation  viewCount  reviewCount  \
# 0     서울시 강남구 신사동 557-25 끌레르빌 1F         4.8   526248.0        131.0
# 1          서울시 강남구 신사동 518-15 B1         4.8    37905.0         48.0
# 2           서울시 강남구 신사동 525-2 1F         4.7    63134.0         91.0
# 3           서울시 강남구 신사동 525-9 1F         4.7   173210.0         86.0
# 4           서울시 강남구 신사동 539 대화빌딩         4.6   463574.0        133.0
# ...                          ...         ...        ...          ...
# 4074          서울시 송파구 잠실동 205-16         4.3   350611.0        189.0
# 4075         서울시 송파구 송파동 42-6 2F         4.3   171791.0         93.0
# 4076           서울시 송파구 송파동 48-15         4.3    35465.0         38.0
# 4077     서울시 송파구 방이동 93 103-104호         4.3    38285.0         30.0
# 4078       서울시 송파구 잠실동 207-17 1F         4.3   133238.0         47.0
#
#               foodType    price                                runTime
# 0       이자카야 / 오뎅 / 꼬치  3만원-4만원                          18:00 - 01:00
# 1                까스 요리   만원-2만원                          11:30 - 21:00
# 2      브런치 / 버거 / 샌드위치   만원-2만원                          11:30 - 22:00
# 3             카페 / 디저트   만원-2만원                          12:30 - 19:30
# 4       이자카야 / 오뎅 / 꼬치  2만원-3만원  월-목: 17:30 - 01:00 금-토: 17:30 - 02:00
# ...                ...      ...                                    ...
# 4074  한정식 / 백반 / 정통 한식    만원 미만                          11:30 - 21:30
# 4075             기타 양식   만원-2만원  화-토: 11:30 - 22:30 일-월: 11:30 - 22:00
# 4076          카페 / 디저트    만원 미만    수-금: 11:00 - 14:00 토: 11:00 - 17:00
# 4077         닭 / 오리 요리   만원-2만원  월-금: 17:00 - 23:00 토-일: 16:00 - 23:00
# 4078             기타 중식   만원-2만원                          14:00 - 24:00
#
# [4079 rows x 8 columns]
#                                                   title  \
# 0                                                   미라이
# 1                                                  상진식감
# 2      패티앤베지스\n                                    (신사)
# 3                                                   삐아프
# 4                                             와라야키 쿠이신보
# ...                                                 ...
# 4094                                            정목누룽지백숙
# 4095  원조마포소금구이\n                                    ...
# 4096                                               용기수산
# 4097  놀부유황오리진흙구이\n                                  ...
# 4098                                                더빛남
#
#                         location  estimation  viewCount  reviewCount  \
# 0     서울시 강남구 신사동 557-25 끌레르빌 1F         4.8   526248.0        131.0
# 1          서울시 강남구 신사동 518-15 B1         4.8    37905.0         48.0
# 2           서울시 강남구 신사동 525-2 1F         4.7    63134.0         91.0
# 3           서울시 강남구 신사동 525-9 1F         4.7   173210.0         86.0
# 4           서울시 강남구 신사동 539 대화빌딩         4.6   463574.0        133.0
# ...                          ...         ...        ...          ...
# 4094          서울시 송파구 방이동 196-15         4.3    18447.0         16.0
# 4095           서울시 송파구 방이동 58 1F         4.3    14217.0         16.0
# 4096             서울시 송파구 가락동 600         4.3    24571.0         15.0
# 4097     서울시 송파구 방이동 109-10 1-2F         4.3    32033.0         14.0
# 4098         서울시 송파구 송파동 50-9 1F         4.3     5944.0          9.0
#
#              foodType    price                                runTime
# 0      이자카야 / 오뎅 / 꼬치  3만원-4만원                          18:00 - 01:00
# 1               까스 요리   만원-2만원                          11:30 - 21:00
# 2     브런치 / 버거 / 샌드위치   만원-2만원                          11:30 - 22:00
# 3            카페 / 디저트   만원-2만원                          12:30 - 19:30
# 4      이자카야 / 오뎅 / 꼬치  2만원-3만원  월-목: 17:30 - 01:00 금-토: 17:30 - 02:00
# ...               ...      ...                                    ...
# 4094        닭 / 오리 요리   만원-2만원                          11:00 - 22:00
# 4095            고기 요리   만원-2만원                          12:00 - 22:00
# 4096           해산물 요리  3만원-4만원                          09:00 - 23:00
# 4097        닭 / 오리 요리   4만원 이상                          10:00 - 22:00
# 4098           베트남 음식    만원 미만                                   None
#
# [4099 rows x 8 columns]
#                                                  title  \
# 0                                                  미라이
# 1                                                 상진식감
# 2     패티앤베지스\n                                    (신사)
# 3                                                  삐아프
# 4                                            와라야키 쿠이신보
# ...                                                ...
# 4114                                         방이샤브샤브칼국수
# 4115                                              온달수산
# 4116    마초야\n                                    (송파점)
# 4117                                             하우스서울
# 4118                                              흥도식당
#
#                                   location  estimation  viewCount  \
# 0               서울시 강남구 신사동 557-25 끌레르빌 1F         4.8   526248.0
# 1                    서울시 강남구 신사동 518-15 B1         4.8    37905.0
# 2                     서울시 강남구 신사동 525-2 1F         4.7    63134.0
# 3                     서울시 강남구 신사동 525-9 1F         4.7   173210.0
# 4                     서울시 강남구 신사동 539 대화빌딩         4.6   463574.0
# ...                                    ...         ...        ...
# 4114                     서울시 송파구 방이동 213-8         4.2    50641.0
# 4115              서울시 송파구 가락동 600 농수산물도매시장         4.2    62969.0
# 4116                  서울시 송파구 석촌동 280-8 1F         4.2     9161.0
# 4117                     서울시 송파구 잠실동 195-6         4.2     6737.0
# 4118  서울시 송파구 문정동 643-1 엠스테이트 B동 B1 155-1호         4.2    14506.0
#
#       reviewCount         foodType    price  \
# 0           131.0   이자카야 / 오뎅 / 꼬치  3만원-4만원
# 1            48.0            까스 요리   만원-2만원
# 2            91.0  브런치 / 버거 / 샌드위치   만원-2만원
# 3            86.0         카페 / 디저트   만원-2만원
# 4           133.0   이자카야 / 오뎅 / 꼬치  2만원-3만원
# ...           ...              ...      ...
# 4114         53.0        국수 / 면 요리    만원 미만
# 4115         27.0           해산물 요리  2만원-3만원
# 4116         16.0            까스 요리    만원 미만
# 4117         15.0         카페 / 디저트    만원 미만
# 4118         17.0            까스 요리   만원-2만원
#
#                                     runTime
# 0                             18:00 - 01:00
# 1                             11:30 - 21:00
# 2                             11:30 - 22:00
# 3                             12:30 - 19:30
# 4     월-목: 17:30 - 01:00 금-토: 17:30 - 02:00
# ...                                     ...
# 4114                          11:00 - 22:00
# 4115                          09:00 - 21:00
# 4116                                   None
# 4117  월-금: 08:00 - 20:00 토-일: 11:00 - 20:00
# 4118                                   None
#
# [4119 rows x 8 columns]
#                                                  title  \
# 0                                                  미라이
# 1                                                 상진식감
# 2     패티앤베지스\n                                    (신사)
# 3                                                  삐아프
# 4                                            와라야키 쿠이신보
# ...                                                ...
# 4134    바토스\n                                    (잠실점)
# 4135                                               비채나
# 4136                                             얼터너티브
# 4137                                             부일갈매기
# 4138    팀호완\n                                    (잠실점)
#
#                            location  estimation  viewCount  reviewCount  \
# 0        서울시 강남구 신사동 557-25 끌레르빌 1F         4.8   526248.0        131.0
# 1             서울시 강남구 신사동 518-15 B1         4.8    37905.0         48.0
# 2              서울시 강남구 신사동 525-2 1F         4.7    63134.0         91.0
# 3              서울시 강남구 신사동 525-9 1F         4.7   173210.0         86.0
# 4              서울시 강남구 신사동 539 대화빌딩         4.6   463574.0        133.0
# ...                             ...         ...        ...          ...
# 4134  서울시 송파구 잠실동 40-1 롯데백화점 잠실점 B1         4.1   226800.0        111.0
# 4135      서울시 송파구 신천동 29 롯데월드타워 81F         4.1    84428.0         18.0
# 4136             서울시 송파구 송파동 131-25         4.1    25136.0         59.0
# 4137             서울시 송파구 잠실동 242-22         4.1    45264.0         32.0
# 4138  서울시 송파구 잠실동 40-1 롯데백화점 잠실점 2F         4.1    42858.0         38.0
#
#               foodType    price                                runTime
# 0       이자카야 / 오뎅 / 꼬치  3만원-4만원                          18:00 - 01:00
# 1                까스 요리   만원-2만원                          11:30 - 21:00
# 2      브런치 / 버거 / 샌드위치   만원-2만원                          11:30 - 22:00
# 3             카페 / 디저트   만원-2만원                          12:30 - 19:30
# 4       이자카야 / 오뎅 / 꼬치  2만원-3만원  월-목: 17:30 - 01:00 금-토: 17:30 - 02:00
# ...                ...      ...                                    ...
# 4134             남미 음식   만원-2만원                          11:30 - 22:00
# 4135  한정식 / 백반 / 정통 한식   4만원 이상                          10:00 - 21:00
# 4136          카페 / 디저트    만원 미만                          11:00 - 22:00
# 4137             고기 요리   만원-2만원                          17:00 - 23:00
# 4138           딤섬 / 만두   만원-2만원                          11:30 - 21:30
#
# [4139 rows x 8 columns]
#                                                   title  \
# 0                                                   미라이
# 1                                                  상진식감
# 2      패티앤베지스\n                                    (신사)
# 3                                                   삐아프
# 4                                             와라야키 쿠이신보
# ...                                                 ...
# 4153                                               명서식당
# 4154                                               명가수산
# 4155                                            그릴210버거
# 4156                                                 만주
# 4157  광화문갈비\n                                    (석촌...
#
#                           location  estimation  viewCount  reviewCount  \
# 0       서울시 강남구 신사동 557-25 끌레르빌 1F         4.8   526248.0        131.0
# 1            서울시 강남구 신사동 518-15 B1         4.8    37905.0         48.0
# 2             서울시 강남구 신사동 525-2 1F         4.7    63134.0         91.0
# 3             서울시 강남구 신사동 525-9 1F         4.7   173210.0         86.0
# 4             서울시 강남구 신사동 539 대화빌딩         4.6   463574.0        133.0
# ...                            ...         ...        ...          ...
# 4153             서울시 송파구 잠실동 206-1         4.1     5476.0          8.0
# 4154  서울시 송파구 가락동 600 가락동 농수산물도매시장         4.1    11675.0         14.0
# 4155     서울시 송파구 송파동 112-3 황제빌딩 1F         4.1    10596.0         11.0
# 4156           서울시 송파구 방이동 60-5 2F         4.1    11839.0         11.0
# 4157        서울시 송파구 송파동 58 대성빌딩 6F         4.1     5564.0          8.0
#
#              foodType    price                                runTime
# 0      이자카야 / 오뎅 / 꼬치  3만원-4만원                          18:00 - 01:00
# 1               까스 요리   만원-2만원                          11:30 - 21:00
# 2     브런치 / 버거 / 샌드위치   만원-2만원                          11:30 - 22:00
# 3            카페 / 디저트   만원-2만원                          12:30 - 19:30
# 4      이자카야 / 오뎅 / 꼬치  2만원-3만원  월-목: 17:30 - 01:00 금-토: 17:30 - 02:00
# ...               ...      ...                                    ...
# 4153           회 / 스시   만원-2만원                                   None
# 4154           해산물 요리   만원-2만원                          08:30 - 23:00
# 4155  브런치 / 버거 / 샌드위치    만원 미만                          11:30 - 20:00
# 4156   이자카야 / 오뎅 / 꼬치   만원-2만원                          16:00 - 05:00
# 4157            고기 요리   4만원 이상                          11:00 - 22:00
#
# [4158 rows x 8 columns]
#                                                  title  \
# 0                                                  미라이
# 1                                                 상진식감
# 2     패티앤베지스\n                                    (신사)
# 3                                                  삐아프
# 4                                            와라야키 쿠이신보
# ...                                                ...
# 4173                                            식당 NeO
# 4174     청와옥\n                                    (본점)
# 4175                                               라멘쨩
# 4176                                               소미연
# 4177                                                콘메
#
#                           location  estimation  viewCount  reviewCount  \
# 0       서울시 강남구 신사동 557-25 끌레르빌 1F         4.8   526248.0        131.0
# 1            서울시 강남구 신사동 518-15 B1         4.8    37905.0         48.0
# 2             서울시 강남구 신사동 525-2 1F         4.7    63134.0         91.0
# 3             서울시 강남구 신사동 525-9 1F         4.7   173210.0         86.0
# 4             서울시 강남구 신사동 539 대화빌딩         4.6   463574.0        133.0
# ...                            ...         ...        ...          ...
# 4173               서울시 송파구 삼전동 3-1         4.0     2749.0          7.0
# 4174     서울시 송파구 방이동 177-3 반도빌딩 1F         4.0    33204.0         37.0
# 4175  서울시 송파구 신천동 7 장미종합상가B동 B1 6호         4.0    38007.0         31.0
# 4176             서울시 송파구 석촌동 273-2         4.0    19102.0         21.0
# 4177           서울시 송파구 송파동 85-5 1F         4.0    24928.0         24.0
#
#              foodType    price                                runTime
# 0      이자카야 / 오뎅 / 꼬치  3만원-4만원                          18:00 - 01:00
# 1               까스 요리   만원-2만원                          11:30 - 21:00
# 2     브런치 / 버거 / 샌드위치   만원-2만원                          11:30 - 22:00
# 3            카페 / 디저트   만원-2만원                          12:30 - 19:30
# 4      이자카야 / 오뎅 / 꼬치  2만원-3만원  월-목: 17:30 - 01:00 금-토: 17:30 - 02:00
# ...               ...      ...                                    ...
# 4173    정통 일식 / 일반 일식  2만원-3만원                          17:30 - 23:00
# 4174      탕 / 찌개 / 전골   만원-2만원                          08:00 - 22:00
# 4175     라멘 / 소바 / 우동    만원 미만                          11:00 - 14:00
# 4176    정통 중식 / 일반 중식     None                                   None
# 4177             이탈리안  2만원-3만원                          12:00 - 22:30
#
# [4178 rows x 8 columns]
#                                                  title  \
# 0                                                  미라이
# 1                                                 상진식감
# 2     패티앤베지스\n                                    (신사)
# 3                                                  삐아프
# 4                                            와라야키 쿠이신보
# ...                                                ...
# 4193                                              공주떡집
# 4194                                           호이안로스터리
# 4195                                            엄지손칼국수
# 4196                                              중화일상
# 4197   흥도식당\n                                    (2호점)
#
#                            location  estimation  viewCount  reviewCount  \
# 0        서울시 강남구 신사동 557-25 끌레르빌 1F         4.8   526248.0        131.0
# 1             서울시 강남구 신사동 518-15 B1         4.8    37905.0         48.0
# 2              서울시 강남구 신사동 525-2 1F         4.7    63134.0         91.0
# 3              서울시 강남구 신사동 525-9 1F         4.7   173210.0         86.0
# 4              서울시 강남구 신사동 539 대화빌딩         4.6   463574.0        133.0
# ...                             ...         ...        ...          ...
# 4193  서울시 송파구 잠실동 40-1 롯데백화점 잠실점 B1         4.0    59180.0         25.0
# 4194      서울시 송파구 문정동 642-3 B동 115호         4.0     7281.0          6.0
# 4195              서울시 송파구 송파동 148-3         4.0     8508.0         15.0
# 4196            서울시 송파구 송파동 20-6 1F         4.0     7302.0          7.0
# 4197            서울시 송파구 오금동 23-3 1F         4.0     5134.0         13.0
#
#              foodType    price                                runTime
# 0      이자카야 / 오뎅 / 꼬치  3만원-4만원                          18:00 - 01:00
# 1               까스 요리   만원-2만원                          11:30 - 21:00
# 2     브런치 / 버거 / 샌드위치   만원-2만원                          11:30 - 22:00
# 3            카페 / 디저트   만원-2만원                          12:30 - 19:30
# 4      이자카야 / 오뎅 / 꼬치  2만원-3만원  월-목: 17:30 - 01:00 금-토: 17:30 - 02:00
# ...               ...      ...                                    ...
# 4193         카페 / 디저트    만원 미만  월-금: 10:30 - 20:00 토-일: 10:30 - 20:30
# 4194         카페 / 디저트    만원 미만                                   None
# 4195        국수 / 면 요리    만원 미만                          11:30 - 21:00
# 4196    정통 중식 / 일반 중식    만원 미만                                   None
# 4197            까스 요리   만원-2만원                                   None
#
# [4198 rows x 8 columns]
#                                                   title  \
# 0                                                   미라이
# 1                                                  상진식감
# 2      패티앤베지스\n                                    (신사)
# 3                                                   삐아프
# 4                                             와라야키 쿠이신보
# ...                                                 ...
# 4213                                                고도식
# 4214  이월로스터스\n                                    (송파점)
# 4215    스시작\n                                    (방이본점)
# 4216  라세느\n                                    (롯데호텔월드)
# 4217                                              모토쿠라시
#
#                         location  estimation  viewCount  reviewCount  \
# 0     서울시 강남구 신사동 557-25 끌레르빌 1F         4.8   526248.0        131.0
# 1          서울시 강남구 신사동 518-15 B1         4.8    37905.0         48.0
# 2           서울시 강남구 신사동 525-2 1F         4.7    63134.0         91.0
# 3           서울시 강남구 신사동 525-9 1F         4.7   173210.0         86.0
# 4           서울시 강남구 신사동 539 대화빌딩         4.6   463574.0        133.0
# ...                          ...         ...        ...          ...
# 4213            서울시 송파구 송파동 55-7         3.9    27185.0         37.0
# 4214            서울시 송파구 송파동 51-7         3.9    63588.0         87.0
# 4215             서울시 송파구 방이동 203         3.9    45638.0         22.0
# 4216  서울시 송파구 잠실동 40-1 롯데호텔월드 2F         3.9    74071.0         48.0
# 4217       서울시 송파구 송파동 11-2 202호         3.9    83278.0         43.0
#
#              foodType    price                                runTime
# 0      이자카야 / 오뎅 / 꼬치  3만원-4만원                          18:00 - 01:00
# 1               까스 요리   만원-2만원                          11:30 - 21:00
# 2     브런치 / 버거 / 샌드위치   만원-2만원                          11:30 - 22:00
# 3            카페 / 디저트   만원-2만원                          12:30 - 19:30
# 4      이자카야 / 오뎅 / 꼬치  2만원-3만원  월-목: 17:30 - 01:00 금-토: 17:30 - 02:00
# ...               ...      ...                                    ...
# 4213            고기 요리   만원-2만원                          17:00 - 24:00
# 4214         카페 / 디저트    만원 미만  일-목: 09:30 - 22:30 금-토: 09:30 - 23:00
# 4215           회 / 스시   4만원 이상                          12:00 - 22:00
# 4216               뷔페   4만원 이상  월-금: 07:00 - 21:00 토-일: 07:00 - 22:00
# 4217   이자카야 / 오뎅 / 꼬치  2만원-3만원                          17:30 - 24:00
#
# [4218 rows x 8 columns]
#                                                   title  \
# 0                                                   미라이
# 1                                                  상진식감
# 2      패티앤베지스\n                                    (신사)
# 3                                                   삐아프
# 4                                             와라야키 쿠이신보
# ...                                                 ...
# 4233                                                포유티
# 4234                                                 가일
# 4235                                               연어식당
# 4236  디라이프스타일키친\n                                   ...
# 4237  화덕고깃간\n                                    (잠실...
#
#                                      location  estimation  viewCount  \
# 0                  서울시 강남구 신사동 557-25 끌레르빌 1F         4.8   526248.0
# 1                       서울시 강남구 신사동 518-15 B1         4.8    37905.0
# 2                        서울시 강남구 신사동 525-2 1F         4.7    63134.0
# 3                        서울시 강남구 신사동 525-9 1F         4.7   173210.0
# 4                        서울시 강남구 신사동 539 대화빌딩         4.6   463574.0
# ...                                       ...         ...        ...
# 4233                       서울시 송파구 방이동 208-18         3.9    32525.0
# 4234                         서울시 송파구 방이동 48-7         3.9    81616.0
# 4235  서울시 송파구 신천동 11-4 잠실 푸르지오월드마크 상가 1F 132호         3.9    57941.0
# 4236                  서울시 송파구 신천동 29 롯데월드몰 5F         3.9    16255.0
# 4237                   서울시 송파구 잠실동 191-5 운관빌딩         3.9    11942.0
#
#       reviewCount         foodType    price  \
# 0           131.0   이자카야 / 오뎅 / 꼬치  3만원-4만원
# 1            48.0            까스 요리   만원-2만원
# 2            91.0  브런치 / 버거 / 샌드위치   만원-2만원
# 3            86.0         카페 / 디저트   만원-2만원
# 4           133.0   이자카야 / 오뎅 / 꼬치  2만원-3만원
# ...           ...              ...      ...
# 4233         34.0           베트남 음식    만원 미만
# 4234         32.0   이자카야 / 오뎅 / 꼬치  2만원-3만원
# 4235         34.0           회 / 스시  2만원-3만원
# 4236         10.0            퓨전 양식  2만원-3만원
# 4237         10.0            고기 요리   만원-2만원
#
#                                     runTime
# 0                             18:00 - 01:00
# 1                             11:30 - 21:00
# 2                             11:30 - 22:00
# 3                             12:30 - 19:30
# 4     월-목: 17:30 - 01:00 금-토: 17:30 - 02:00
# ...                                     ...
# 4233                          11:00 - 22:00
# 4234                          15:00 - 01:30
# 4235    월-금: 11:30 - 24:00 토: 17:00 - 23:00
# 4236                                   None
# 4237                          16:00 - 01:00
#
# [4238 rows x 8 columns]
#                                                   title  \
# 0                                                   미라이
# 1                                                  상진식감
# 2      패티앤베지스\n                                    (신사)
# 3                                                   삐아프
# 4                                             와라야키 쿠이신보
# ...                                                 ...
# 4253  베테랑칼국수\n                                    (롯...
# 4254                                              리프커피바
# 4255    그릭데이\n                                    (잠실점)
# 4256                                               커넥트투
# 4257                                               모범가츠
#
#                            location  estimation  viewCount  reviewCount  \
# 0        서울시 강남구 신사동 557-25 끌레르빌 1F         4.8   526248.0        131.0
# 1             서울시 강남구 신사동 518-15 B1         4.8    37905.0         48.0
# 2              서울시 강남구 신사동 525-2 1F         4.7    63134.0         91.0
# 3              서울시 강남구 신사동 525-9 1F         4.7   173210.0         86.0
# 4              서울시 강남구 신사동 539 대화빌딩         4.6   463574.0        133.0
# ...                             ...         ...        ...          ...
# 4253  서울시 송파구 잠실동 40-1 롯데백화점 잠실점 B1         3.9    31874.0         17.0
# 4254              서울시 송파구 송파동 39-15         3.9     2631.0         10.0
# 4255            서울시 송파구 송파동 47-3 1F         3.9     2867.0          6.0
# 4256           서울시 송파구 신천동 29 롯데월드몰         3.9    10132.0         16.0
# 4257               서울시 송파구 문정동 53-7         3.9    14926.0         10.0
#
#              foodType    price                                runTime
# 0      이자카야 / 오뎅 / 꼬치  3만원-4만원                          18:00 - 01:00
# 1               까스 요리   만원-2만원                          11:30 - 21:00
# 2     브런치 / 버거 / 샌드위치   만원-2만원                          11:30 - 22:00
# 3            카페 / 디저트   만원-2만원                          12:30 - 19:30
# 4      이자카야 / 오뎅 / 꼬치  2만원-3만원  월-목: 17:30 - 01:00 금-토: 17:30 - 02:00
# ...               ...      ...                                    ...
# 4253        국수 / 면 요리    만원 미만  월-목: 10:30 - 20:00 금-일: 10:30 - 20:30
# 4254         카페 / 디저트    만원 미만                                   None
# 4255         카페 / 디저트    만원 미만                          10:00 - 22:00
# 4256         카페 / 디저트    만원 미만                          10:30 - 22:00
# 4257            까스 요리    만원 미만                          11:00 - 21:00
#
# [4258 rows x 8 columns]
#                                                  title  \
# 0                                                  미라이
# 1                                                 상진식감
# 2     패티앤베지스\n                                    (신사)
# 3                                                  삐아프
# 4                                            와라야키 쿠이신보
# ...                                                ...
# 4273                                             프레스커피
# 4274                                              차고버거
# 4275                                             니꾸바시야
# 4276                                      Le Sud Seoul
# 4277                                              레스파스
#
#                          location  estimation  viewCount  reviewCount  \
# 0      서울시 강남구 신사동 557-25 끌레르빌 1F         4.8   526248.0        131.0
# 1           서울시 강남구 신사동 518-15 B1         4.8    37905.0         48.0
# 2            서울시 강남구 신사동 525-2 1F         4.7    63134.0         91.0
# 3            서울시 강남구 신사동 525-9 1F         4.7   173210.0         86.0
# 4            서울시 강남구 신사동 539 대화빌딩         4.6   463574.0        133.0
# ...                           ...         ...        ...          ...
# 4273          서울시 송파구 송파동 42-6 4F         3.8    28481.0         37.0
# 4274  서울시 송파구 방이동 49-8 엘엠오오피스텔 1F         3.8    38300.0         40.0
# 4275       서울시 송파구 방이동 99-22 103호         3.8    50209.0         13.0
# 4276    서울시 송파구 방이동 164-5 에이치에스빌딩         3.8    18486.0         26.0
# 4277  서울시 송파구 신천동 29-1 소피텔앰배서더 6F         3.8     4822.0         12.0
#
#              foodType    price  \
# 0      이자카야 / 오뎅 / 꼬치  3만원-4만원
# 1               까스 요리   만원-2만원
# 2     브런치 / 버거 / 샌드위치   만원-2만원
# 3            카페 / 디저트   만원-2만원
# 4      이자카야 / 오뎅 / 꼬치  2만원-3만원
# ...               ...      ...
# 4273         카페 / 디저트    만원 미만
# 4274  브런치 / 버거 / 샌드위치    만원 미만
# 4275            기타 일식  3만원-4만원
# 4276         카페 / 디저트    만원 미만
# 4277         카페 / 디저트  2만원-3만원
#
#                                                 runTime
# 0                                         18:00 - 01:00
# 1                                         11:30 - 21:00
# 2                                         11:30 - 22:00
# 3                                         12:30 - 19:30
# 4                 월-목: 17:30 - 01:00 금-토: 17:30 - 02:00
# ...                                                 ...
# 4273                                      12:00 - 22:00
# 4274                월: 11:30 - 15:00 화-일: 11:30 - 22:00
# 4275                                      18:00 - 02:00
# 4276  월-금: 07:30 - 22:00 토: 10:00 - 22:00 일: 10:00 -...
# 4277                                      10:00 - 22:00
#
# [4278 rows x 8 columns]
#                                                   title  \
# 0                                                   미라이
# 1                                                  상진식감
# 2      패티앤베지스\n                                    (신사)
# 3                                                   삐아프
# 4                                             와라야키 쿠이신보
# ...                                                 ...
# 4293                                                뽕사부
# 4294  가렛팝콘샵\n                                    (롯데...
# 4295                                                베이크
# 4296  프로퍼커피바\n                                    (2호점)
# 4297  만족오향족발\n                                    (잠...
#
#                           location  estimation  viewCount  reviewCount  \
# 0       서울시 강남구 신사동 557-25 끌레르빌 1F         4.8   526248.0        131.0
# 1            서울시 강남구 신사동 518-15 B1         4.8    37905.0         48.0
# 2             서울시 강남구 신사동 525-2 1F         4.7    63134.0         91.0
# 3             서울시 강남구 신사동 525-9 1F         4.7   173210.0         86.0
# 4             서울시 강남구 신사동 539 대화빌딩         4.6   463574.0        133.0
# ...                            ...         ...        ...          ...
# 4293               서울시 송파구 방이동 180         3.8     4621.0         16.0
# 4294       서울시 송파구 신천동 29 롯데월드몰 B1         3.8    33038.0         43.0
# 4295  서울시 송파구 잠실동 40-1 롯데백화점잠실점 B1         3.8    19506.0         21.0
# 4296            서울시 송파구 방이동 217 1F         3.8      643.0          6.0
# 4297             서울시 송파구 잠실동 189-4         3.8    10600.0         13.0
#
#              foodType    price                                runTime
# 0      이자카야 / 오뎅 / 꼬치  3만원-4만원                          18:00 - 01:00
# 1               까스 요리   만원-2만원                          11:30 - 21:00
# 2     브런치 / 버거 / 샌드위치   만원-2만원                          11:30 - 22:00
# 3            카페 / 디저트   만원-2만원                          12:30 - 19:30
# 4      이자카야 / 오뎅 / 꼬치  2만원-3만원  월-목: 17:30 - 01:00 금-토: 17:30 - 02:00
# ...               ...      ...                                    ...
# 4293    정통 중식 / 일반 중식    만원 미만                                   None
# 4294         카페 / 디저트    만원 미만                          10:30 - 22:00
# 4295         카페 / 디저트    만원 미만                          10:30 - 21:00
# 4296         카페 / 디저트    만원 미만                                   None
# 4297            고기 요리   만원-2만원  월-금: 16:00 - 24:00 토-일: 15:00 - 24:00
#
# [4298 rows x 8 columns]
#                                                   title  \
# 0                                                   미라이
# 1                                                  상진식감
# 2      패티앤베지스\n                                    (신사)
# 3                                                   삐아프
# 4                                             와라야키 쿠이신보
# ...                                                 ...
# 4313  을밀대\n                                    (롯데백화...
# 4314                                               동래별장
# 4315                                            젤라떼리아도도
# 4316                                             하라핸즈커피
# 4317   청기와타운\n                                    (잠실점)
#
#                             location  estimation  viewCount  reviewCount  \
# 0         서울시 강남구 신사동 557-25 끌레르빌 1F         4.8   526248.0        131.0
# 1              서울시 강남구 신사동 518-15 B1         4.8    37905.0         48.0
# 2               서울시 강남구 신사동 525-2 1F         4.7    63134.0         91.0
# 3               서울시 강남구 신사동 525-9 1F         4.7   173210.0         86.0
# 4               서울시 강남구 신사동 539 대화빌딩         4.6   463574.0        133.0
# ...                              ...         ...        ...          ...
# 4313  서울시 송파구 잠실동 40-1 롯데백화점 잠실점 11F         3.7    13913.0         17.0
# 4314             서울시 송파구 방이동 63-1 1F         3.7    12250.0         15.0
# 4315             서울시 송파구 송파동 12-5 1F         3.7     7854.0         21.0
# 4316                 서울시 송파구 잠실동 182         3.7    17207.0         20.0
# 4317           서울시 송파구 방이동 109-11 1F         3.7     2959.0          8.0
#
#              foodType    price  \
# 0      이자카야 / 오뎅 / 꼬치  3만원-4만원
# 1               까스 요리   만원-2만원
# 2     브런치 / 버거 / 샌드위치   만원-2만원
# 3            카페 / 디저트   만원-2만원
# 4      이자카야 / 오뎅 / 꼬치  2만원-3만원
# ...               ...      ...
# 4313        국수 / 면 요리   만원-2만원
# 4314           해산물 요리  2만원-3만원
# 4315         카페 / 디저트    만원 미만
# 4316         카페 / 디저트    만원 미만
# 4317            고기 요리  2만원-3만원
#
#                                                 runTime
# 0                                         18:00 - 01:00
# 1                                         11:30 - 21:00
# 2                                         11:30 - 22:00
# 3                                         12:30 - 19:30
# 4                 월-목: 17:30 - 01:00 금-토: 17:30 - 02:00
# ...                                                 ...
# 4313                                      11:00 - 22:00
# 4314                                      17:00 - 04:00
# 4315                                      12:00 - 22:00
# 4316  일: 10:00 - 21:00 월-목: 10:00 - 22:00 금-토: 10:00...
# 4317                                               None
#
# [4318 rows x 8 columns]
#                                                   title  \
# 0                                                   미라이
# 1                                                  상진식감
# 2      패티앤베지스\n                                    (신사)
# 3                                                   삐아프
# 4                                             와라야키 쿠이신보
# ...                                                 ...
# 4333      밸런티\n                                    (본점)
# 4334  항아리닭갈비막국수\n                                   ...
# 4335  파리크라상\n                                    (올림픽점)
# 4336                                        씨젬므쥬르 (휴업중)
# 4337                                              인딕슬로우
#
#                         location  estimation  viewCount  reviewCount  \
# 0     서울시 강남구 신사동 557-25 끌레르빌 1F         4.8   526248.0        131.0
# 1          서울시 강남구 신사동 518-15 B1         4.8    37905.0         48.0
# 2           서울시 강남구 신사동 525-2 1F         4.7    63134.0         91.0
# 3           서울시 강남구 신사동 525-9 1F         4.7   173210.0         86.0
# 4           서울시 강남구 신사동 539 대화빌딩         4.6   463574.0        133.0
# ...                          ...         ...        ...          ...
# 4333       서울시 송파구 석촌동 261-17 1F         3.7    11012.0         10.0
# 4334       서울시 송파구 문정동 618 착한식당촌         3.7    14366.0         14.0
# 4335           서울시 송파구 방이동 88 1F         3.7    13657.0         28.0
# 4336            서울시 송파구 송파동 12-3         3.7    12701.0         14.0
# 4337         서울시 송파구 송파동 55-7 2F         3.7     5263.0         10.0
#
#              foodType    price                                runTime
# 0      이자카야 / 오뎅 / 꼬치  3만원-4만원                          18:00 - 01:00
# 1               까스 요리   만원-2만원                          11:30 - 21:00
# 2     브런치 / 버거 / 샌드위치   만원-2만원                          11:30 - 22:00
# 3            카페 / 디저트   만원-2만원                          12:30 - 19:30
# 4      이자카야 / 오뎅 / 꼬치  2만원-3만원  월-목: 17:30 - 01:00 금-토: 17:30 - 02:00
# ...               ...      ...                                    ...
# 4333         카페 / 디저트    만원 미만                          10:00 - 18:00
# 4334        닭 / 오리 요리   만원-2만원                          11:00 - 22:00
# 4335             베이커리    만원 미만                          07:00 - 23:00
# 4336             이탈리안   만원-2만원                                   None
# 4337            인도 음식   만원-2만원                          11:30 - 22:00
#
# [4338 rows x 8 columns]
#                                                   title  \
# 0                                                   미라이
# 1                                                  상진식감
# 2      패티앤베지스\n                                    (신사)
# 3                                                   삐아프
# 4                                             와라야키 쿠이신보
# ...                                                 ...
# 4353                                              남경막국수
# 4354  아그라\n                                    (롯데에비...
# 4355                                               위커파크
# 4356                                           트라토리아브로도
# 4357                                                 온량
#
#                               location  estimation  viewCount  reviewCount  \
# 0           서울시 강남구 신사동 557-25 끌레르빌 1F         4.8   526248.0        131.0
# 1                서울시 강남구 신사동 518-15 B1         4.8    37905.0         48.0
# 2                 서울시 강남구 신사동 525-2 1F         4.7    63134.0         91.0
# 3                 서울시 강남구 신사동 525-9 1F         4.7   173210.0         86.0
# 4                 서울시 강남구 신사동 539 대화빌딩         4.6   463574.0        133.0
# ...                                ...         ...        ...          ...
# 4353                서울시 송파구 잠실동 207-13         3.6    58166.0         71.0
# 4354  서울시 송파구 신천동 29 롯데백화점에비뉴엘월드타워점 6F         3.6    59490.0         51.0
# 4355                  서울시 송파구 송파동 58-1         3.6    27039.0         34.0
# 4356                 서울시 송파구 방이동 201-3         3.6    11523.0         17.0
# 4357                    서울시 송파구 송파동 47         3.6    39709.0         28.0
#
#              foodType    price                                runTime
# 0      이자카야 / 오뎅 / 꼬치  3만원-4만원                          18:00 - 01:00
# 1               까스 요리   만원-2만원                          11:30 - 21:00
# 2     브런치 / 버거 / 샌드위치   만원-2만원                          11:30 - 22:00
# 3            카페 / 디저트   만원-2만원                          12:30 - 19:30
# 4      이자카야 / 오뎅 / 꼬치  2만원-3만원  월-목: 17:30 - 01:00 금-토: 17:30 - 02:00
# ...               ...      ...                                    ...
# 4353        국수 / 면 요리   만원-2만원                          11:00 - 22:00
# 4354            인도 음식  2만원-3만원                          11:30 - 22:00
# 4355         카페 / 디저트    만원 미만  월-금: 10:30 - 22:00 토-일: 12:00 - 22:00
# 4356             이탈리안  2만원-3만원    월: 18:00 - 22:30 화-토: 12:00 - 22:30
# 4357            기타 양식   만원-2만원                          12:00 - 21:00
#
# [4358 rows x 8 columns]
#                                                   title  \
# 0                                                   미라이
# 1                                                  상진식감
# 2      패티앤베지스\n                                    (신사)
# 3                                                   삐아프
# 4                                             와라야키 쿠이신보
# ...                                                 ...
# 4373                                              섬맛의공방
# 4374                                             아낙네그루브
# 4375  돈부리파스타\n                                    (송...
# 4376                                             입분식가정집
# 4377                                               정순함박
#
#                         location  estimation  viewCount  reviewCount  \
# 0     서울시 강남구 신사동 557-25 끌레르빌 1F         4.8   526248.0        131.0
# 1          서울시 강남구 신사동 518-15 B1         4.8    37905.0         48.0
# 2           서울시 강남구 신사동 525-2 1F         4.7    63134.0         91.0
# 3           서울시 강남구 신사동 525-9 1F         4.7   173210.0         86.0
# 4           서울시 강남구 신사동 539 대화빌딩         4.6   463574.0        133.0
# ...                          ...         ...        ...          ...
# 4373             서울시 송파구 문정동 618         3.6     7469.0         10.0
# 4374         서울시 송파구 송파동 42 4-5F         3.6     7440.0         16.0
# 4375            서울시 송파구 송파동 42-6         3.6     1971.0          9.0
# 4376         서울시 송파구 송파동 51-4 2F         3.6     4174.0          6.0
# 4377         서울시 송파구 신천동 7 장미B상가         3.6     7691.0         11.0
#
#              foodType    price                                runTime
# 0      이자카야 / 오뎅 / 꼬치  3만원-4만원                          18:00 - 01:00
# 1               까스 요리   만원-2만원                          11:30 - 21:00
# 2     브런치 / 버거 / 샌드위치   만원-2만원                          11:30 - 22:00
# 3            카페 / 디저트   만원-2만원                          12:30 - 19:30
# 4      이자카야 / 오뎅 / 꼬치  2만원-3만원  월-목: 17:30 - 01:00 금-토: 17:30 - 02:00
# ...               ...      ...                                    ...
# 4373   이자카야 / 오뎅 / 꼬치  2만원-3만원                                   None
# 4374      치킨 / 호프 / 펍   만원-2만원                                   None
# 4375            퓨전 일식   만원-2만원                                   None
# 4376            기타 한식    만원 미만                                   None
# 4377       스테이크 / 바베큐    만원 미만                          11:00 - 20:00
#
# [4378 rows x 8 columns]
#                                                  title  \
# 0                                                  미라이
# 1                                                 상진식감
# 2     패티앤베지스\n                                    (신사)
# 3                                                  삐아프
# 4                                            와라야키 쿠이신보
# ...                                                ...
# 4393                                                 젠
# 4394                                            카페 코히루
# 4395   툇마루밥상\n                                    (본점)
# 4396                                            대갈곱창막창
# 4397                                            장털보설렁탕
#
#                         location  estimation  viewCount  reviewCount  \
# 0     서울시 강남구 신사동 557-25 끌레르빌 1F         4.8   526248.0        131.0
# 1          서울시 강남구 신사동 518-15 B1         4.8    37905.0         48.0
# 2           서울시 강남구 신사동 525-2 1F         4.7    63134.0         91.0
# 3           서울시 강남구 신사동 525-9 1F         4.7   173210.0         86.0
# 4           서울시 강남구 신사동 539 대화빌딩         4.6   463574.0        133.0
# ...                          ...         ...        ...          ...
# 4393       서울시 송파구 송파동 51-3 102호         3.5     6920.0         16.0
# 4394           서울시 송파구 송파동 48-16         3.5     8841.0         12.0
# 4395           서울시 송파구 문정동 46-11         3.5    58046.0         35.0
# 4396            서울시 송파구 송파동 39-9         3.5    10763.0         19.0
# 4397              서울시 송파구 오금동 89         3.5    15262.0         18.0
#
#               foodType    price                                runTime
# 0       이자카야 / 오뎅 / 꼬치  3만원-4만원                          18:00 - 01:00
# 1                까스 요리   만원-2만원                          11:30 - 21:00
# 2      브런치 / 버거 / 샌드위치   만원-2만원                          11:30 - 22:00
# 3             카페 / 디저트   만원-2만원                          12:30 - 19:30
# 4       이자카야 / 오뎅 / 꼬치  2만원-3만원  월-목: 17:30 - 01:00 금-토: 17:30 - 02:00
# ...                ...      ...                                    ...
# 4393     정통 일식 / 일반 일식   만원-2만원                                   None
# 4394          카페 / 디저트    만원 미만                          12:00 - 21:00
# ...
# ...                ...      ...
# 17070       스테이크 / 바베큐   만원-2만원
# 17071         카페 / 디저트    만원 미만
# 17072      탕 / 찌개 / 전골    만원 미만
# 17073  브런치 / 버거 / 샌드위치    만원 미만
# 17074           베트남 음식    만원 미만
#
#                                                  runTime
# 0                                          18:00 - 01:00
# 1                                          11:30 - 21:00
# 2                                          11:30 - 22:00
# 3                                          12:30 - 19:30
# 4                  월-목: 17:30 - 01:00 금-토: 17:30 - 02:00
# ...                                                  ...
# 17070                                      11:30 - 23:00
# 17071                                               None
# 17072                                      08:30 - 22:00
# 17073  화: 12:00 - 15:00 수-금: 12:00 - 20:00 토-일: 11:00...
# 17074                                      10:30 - 22:00
#
# [17075 rows x 8 columns]
#                                                    title  \
# 0                                                    미라이
# 1                                                   상진식감
# 2       패티앤베지스\n                                    (신사)
# 3                                                    삐아프
# 4                                              와라야키 쿠이신보
# ...                                                  ...
# 17090  멘야산다이메\n                                    (홍대점)
# 17091    부탄츄\n                                    (홍대본점)
# 17092                                           에스프레소부티크
# 17093                                                 향미
# 17094                                                  안
#
#                          location  estimation  viewCount  reviewCount  \
# 0      서울시 강남구 신사동 557-25 끌레르빌 1F         4.8   526248.0        131.0
# 1           서울시 강남구 신사동 518-15 B1         4.8    37905.0         48.0
# 2            서울시 강남구 신사동 525-2 1F         4.7    63134.0         91.0
# 3            서울시 강남구 신사동 525-9 1F         4.7   173210.0         86.0
# 4            서울시 강남구 신사동 539 대화빌딩         4.6   463574.0        133.0
# ...                           ...         ...        ...          ...
# 17090          서울시 마포구 서교동 355-25         3.4    57253.0        207.0
# 17091          서울시 마포구 서교동 330-19         3.4    41948.0        123.0
# 17092          서울시 마포구 연남동 566-60         3.4    33584.0         52.0
# 17093          서울시 마포구 연남동 226-21         3.4    73733.0         86.0
# 17094           서울시 마포구 연남동 387-8         3.4    27058.0         48.0
#
#               foodType    price                                runTime
# 0       이자카야 / 오뎅 / 꼬치  3만원-4만원                          18:00 - 01:00
# 1                까스 요리   만원-2만원                          11:30 - 21:00
# 2      브런치 / 버거 / 샌드위치   만원-2만원                          11:30 - 22:00
# 3             카페 / 디저트   만원-2만원                          12:30 - 19:30
# 4       이자카야 / 오뎅 / 꼬치  2만원-3만원  월-목: 17:30 - 01:00 금-토: 17:30 - 02:00
# ...                ...      ...                                    ...
# 17090     라멘 / 소바 / 우동    만원 미만                          12:00 - 22:00
# 17091     라멘 / 소바 / 우동    만원 미만                          11:30 - 22:00
# 17092         카페 / 디저트    만원 미만  월-금: 12:00 - 23:00 토-일: 11:00 - 23:00
# 17093    정통 중식 / 일반 중식    만원 미만                          11:30 - 22:00
# 17094           베트남 음식   만원-2만원                          12:00 - 22:00
#
# [17095 rows x 8 columns]
#                                                   title  \
# 0                                                   미라이
# 1                                                  상진식감
# 2      패티앤베지스\n                                    (신사)
# 3                                                   삐아프
# 4                                             와라야키 쿠이신보
# ...                                                 ...
# 17110                                             미나리식당
# 17111                                              청년닭발
# 17112                                                도마
# 17113                                                롭다
# 17114                                            치킨인더키친
#
#                          location  estimation  viewCount  reviewCount  \
# 0      서울시 강남구 신사동 557-25 끌레르빌 1F         4.8   526248.0        131.0
# 1           서울시 강남구 신사동 518-15 B1         4.8    37905.0         48.0
# 2            서울시 강남구 신사동 525-2 1F         4.7    63134.0         91.0
# 3            서울시 강남구 신사동 525-9 1F         4.7   173210.0         86.0
# 4            서울시 강남구 신사동 539 대화빌딩         4.6   463574.0        133.0
# ...                           ...         ...        ...          ...
# 17110          서울시 마포구 서교동 366-14         3.4    22146.0         39.0
# 17111          서울시 마포구 동교동 152-18         3.4     6363.0         29.0
# 17112           서울시 마포구 서교동 357-3         3.4    28502.0         24.0
# 17113          서울시 마포구 연남동 260-16         3.4     1479.0          9.0
# 17114          서울시 마포구 서교동 327-22         3.4    13345.0         47.0
#
#               foodType    price                                runTime
# 0       이자카야 / 오뎅 / 꼬치  3만원-4만원                          18:00 - 01:00
# 1                까스 요리   만원-2만원                          11:30 - 21:00
# 2      브런치 / 버거 / 샌드위치   만원-2만원                          11:30 - 22:00
# 3             카페 / 디저트   만원-2만원                          12:30 - 19:30
# 4       이자카야 / 오뎅 / 꼬치  2만원-3만원  월-목: 17:30 - 01:00 금-토: 17:30 - 02:00
# ...                ...      ...                                    ...
# 17110            고기 요리    만원 미만  일-목: 11:30 - 22:00 금-토: 11:30 - 23:00
# 17111        닭 / 오리 요리   만원-2만원  월-금: 15:00 - 04:30 토-일: 13:00 - 04:30
# 17112            고기 요리    만원 미만                          11:30 - 05:00
# 17113         카페 / 디저트    만원 미만                                   None
# 17114        닭 / 오리 요리   만원-2만원  일-목: 16:00 - 24:00 금-토: 16:00 - 01:00
#
# [17115 rows x 8 columns]
#                                                    title  \
# 0                                                    미라이
# 1                                                   상진식감
# 2       패티앤베지스\n                                    (신사)
# 3                                                    삐아프
# 4                                              와라야키 쿠이신보
# ...                                                  ...
# 17130                                                코노미
# 17131    돈수백\n                                    (홍대본점)
# 17132                                           산옥커피로스터스
# 17133  봉대박스파게티\n                                    (...
# 17134    아비꼬\n                                    (홍대본점)
#
#                              location  estimation  viewCount  reviewCount  \
# 0          서울시 강남구 신사동 557-25 끌레르빌 1F         4.8   526248.0        131.0
# 1               서울시 강남구 신사동 518-15 B1         4.8    37905.0         48.0
# 2                서울시 강남구 신사동 525-2 1F         4.7    63134.0         91.0
# 3                서울시 강남구 신사동 525-9 1F         4.7   173210.0         86.0
# 4                서울시 강남구 신사동 539 대화빌딩         4.6   463574.0        133.0
# ...                               ...         ...        ...          ...
# 17130              서울시 마포구 서교동 366-28         3.3    10163.0         14.0
# 17131              서울시 마포구 동교동 164-24         3.3    20918.0         77.0
# 17132         서울시 마포구 동교동 113-85 1,2F         3.3     1865.0          5.0
# 17133       서울시 마포구 서교동 486 서교푸르지오 B1         3.3     4668.0         19.0
# 17134  서울시 마포구 서교동 356-1 서교호텔별관 B106호         3.3    10923.0         64.0
#
#                foodType    price                                runTime
# 0        이자카야 / 오뎅 / 꼬치  3만원-4만원                          18:00 - 01:00
# 1                 까스 요리   만원-2만원                          11:30 - 21:00
# 2       브런치 / 버거 / 샌드위치   만원-2만원                          11:30 - 22:00
# 3              카페 / 디저트   만원-2만원                          12:30 - 19:30
# 4        이자카야 / 오뎅 / 꼬치  2만원-3만원  월-목: 17:30 - 01:00 금-토: 17:30 - 02:00
# ...                 ...      ...                                    ...
# 17130             철판 요리    만원 미만  일-목: 13:00 - 00:30 금-토: 13:00 - 01:30
# 17131       탕 / 찌개 / 전골    만원 미만    월-토: 00:00 - 24:00 일: 00:00 - 22:00
# 17132          카페 / 디저트    만원 미만                          10:00 - 22:00
# 17133              이탈리안    만원 미만                          11:30 - 21:30
# 17134  돈부리 / 일본 카레 / 벤토    만원 미만                          11:30 - 21:30
#
# [17135 rows x 8 columns]
#                                                    title  \
# 0                                                    미라이
# 1                                                   상진식감
# 2       패티앤베지스\n                                    (신사)
# 3                                                    삐아프
# 4                                              와라야키 쿠이신보
# ...                                                  ...
# 17150                                               마녀주방
# 17151    빌리엔젤\n                                    (홍대점)
# 17152                                             등불서양주점
# 17153  베트남노상식당\n                                    (...
# 17154                                               모미모미
#
#                          location  estimation  viewCount  reviewCount  \
# 0      서울시 강남구 신사동 557-25 끌레르빌 1F         4.8   526248.0        131.0
# 1           서울시 강남구 신사동 518-15 B1         4.8    37905.0         48.0
# 2            서울시 강남구 신사동 525-2 1F         4.7    63134.0         91.0
# 3            서울시 강남구 신사동 525-9 1F         4.7   173210.0         86.0
# 4            서울시 강남구 신사동 539 대화빌딩         4.6   463574.0        133.0
# ...                           ...         ...        ...          ...
# 17150          서울시 마포구 서교동 358-51         3.2     6693.0         19.0
# 17151           서울시 마포구 서교동 343-9         3.2    14391.0         49.0
# 17152          서울시 마포구 연남동 260-49         3.2     7551.0         24.0
# 17153   서울시 마포구 동교동 154-10 진빌딩 1F         3.2    11092.0         25.0
# 17154       서울시 마포구 서교동 328-12 1F         3.2    13554.0         26.0
#
#               foodType    price                                runTime
# 0       이자카야 / 오뎅 / 꼬치  3만원-4만원                          18:00 - 01:00
# 1                까스 요리   만원-2만원                          11:30 - 21:00
# 2      브런치 / 버거 / 샌드위치   만원-2만원                          11:30 - 22:00
# 3             카페 / 디저트   만원-2만원                          12:30 - 19:30
# 4       이자카야 / 오뎅 / 꼬치  2만원-3만원  월-목: 17:30 - 01:00 금-토: 17:30 - 02:00
# ...                ...      ...                                    ...
# 17150             이탈리안    만원 미만    월-토: 12:00 - 22:30 일: 12:00 - 22:00
# 17151         카페 / 디저트    만원 미만                          10:00 - 23:00
# 17152       전통 주점 / 포차  2만원-3만원                          17:30 - 01:00
# 17153           베트남 음식    만원 미만                          11:00 - 23:00
# 17154    정통 일식 / 일반 일식   만원-2만원                          09:30 - 21:30
#
# [17155 rows x 8 columns]
#                                                   title  \
# 0                                                   미라이
# 1                                                  상진식감
# 2      패티앤베지스\n                                    (신사)
# 3                                                   삐아프
# 4                                             와라야키 쿠이신보
# ...                                                 ...
# 17170                                              작당모의
# 17171                                          제임스시카고피자
# 17172                                              카에식탁
# 17173    긴자료코\n                                    (본점)
# 17174  설빙\n                                    (홍대입구역점)
#
#                          location  estimation  viewCount  reviewCount  \
# 0      서울시 강남구 신사동 557-25 끌레르빌 1F         4.8   526248.0        131.0
# 1           서울시 강남구 신사동 518-15 B1         4.8    37905.0         48.0
# 2            서울시 강남구 신사동 525-2 1F         4.7    63134.0         91.0
# 3            서울시 강남구 신사동 525-9 1F         4.7   173210.0         86.0
# 4            서울시 강남구 신사동 539 대화빌딩         4.6   463574.0        133.0
# ...                           ...         ...        ...          ...
# 17170          서울시 마포구 연남동 381-15         3.0     9045.0         20.0
# 17171          서울시 마포구 서교동 346-42         3.0    18329.0         41.0
# 17172          서울시 마포구 동교동 113-20         3.0     4767.0         19.0
# 17173          서울시 마포구 서교동 346-21         3.0    12607.0         21.0
# 17174           서울시 마포구 동교동 162-3         3.0     5857.0         23.0
#
#               foodType    price                                runTime
# 0       이자카야 / 오뎅 / 꼬치  3만원-4만원                          18:00 - 01:00
# 1                까스 요리   만원-2만원                          11:30 - 21:00
# 2      브런치 / 버거 / 샌드위치   만원-2만원                          11:30 - 22:00
# 3             카페 / 디저트   만원-2만원                          12:30 - 19:30
# 4       이자카야 / 오뎅 / 꼬치  2만원-3만원  월-목: 17:30 - 01:00 금-토: 17:30 - 02:00
# ...                ...      ...                                    ...
# 17170         카페 / 디저트    만원 미만                          11:00 - 23:00
# 17171            기타 양식   만원-2만원                          12:00 - 22:30
# 17172    정통 일식 / 일반 일식  2만원-3만원                                   None
# 17173    정통 일식 / 일반 일식    만원 미만                          12:00 - 22:00
# 17174         카페 / 디저트    만원 미만  월-금: 11:00 - 24:00 토-일: 11:00 - 00:30
#
# [17175 rows x 8 columns]
#                                                    title  \
# 0                                                    미라이
# 1                                                   상진식감
# 2       패티앤베지스\n                                    (신사)
# 3                                                    삐아프
# 4                                              와라야키 쿠이신보
# ...                                                  ...
# 17181   빠레뜨한남\n                                    (연남점)
# 17182   박용석스시\n                                    (연남점)
# 17183  스시오블랙컨테이너\n                                   ...
# 17184      콩불\n                                    (홍대점)
# 17185                                               노사이드
#
#                          location  estimation  viewCount  reviewCount  \
# 0      서울시 강남구 신사동 557-25 끌레르빌 1F         4.8   526248.0        131.0
# 1           서울시 강남구 신사동 518-15 B1         4.8    37905.0         48.0
# 2            서울시 강남구 신사동 525-2 1F         4.7    63134.0         91.0
# 3            서울시 강남구 신사동 525-9 1F         4.7   173210.0         86.0
# 4            서울시 강남구 신사동 539 대화빌딩         4.6   463574.0        133.0
# ...                           ...         ...        ...          ...
# 17181       서울시 마포구 연남동 229-56 1F         2.9     2388.0          9.0
# 17182          서울시 마포구 연남동 228-64         2.8     3882.0         22.0
# 17183           서울시 마포구 서교동 358-8         2.7    22083.0         29.0
# 17184           서울시 마포구 서교동 345-1         2.7     9264.0         35.0
# 17185          서울시 마포구 동교동 177-23         2.7   155561.0         68.0
#
#               foodType    price                                runTime
# 0       이자카야 / 오뎅 / 꼬치  3만원-4만원                          18:00 - 01:00
# 1                까스 요리   만원-2만원                          11:30 - 21:00
# 2      브런치 / 버거 / 샌드위치   만원-2만원                          11:30 - 22:00
# 3             카페 / 디저트   만원-2만원                          12:30 - 19:30
# 4       이자카야 / 오뎅 / 꼬치  2만원-3만원  월-목: 17:30 - 01:00 금-토: 17:30 - 02:00
# ...                ...      ...                                    ...
# 17181            퓨전 양식   만원-2만원                                   None
# 17182           회 / 스시   만원-2만원                          11:00 - 02:00
# 17183               뷔페   만원-2만원                          11:00 - 22:00
# 17184            고기 요리    만원 미만  월-목: 10:30 - 24:00 금-토: 10:30 - 01:00
# 17185            철판 요리   만원-2만원                                   None
#
# [17186 rows x 8 columns]

# %%
mangoData
# Out:
#                                                    title  \
# 0                                                    미라이
# 1                                                   상진식감
# 2       패티앤베지스\n                                    (신사)
# 3                                                    삐아프
# 4                                              와라야키 쿠이신보
# ...                                                  ...
# 17181   빠레뜨한남\n                                    (연남점)
# 17182   박용석스시\n                                    (연남점)
# 17183  스시오블랙컨테이너\n                                   ...
# 17184      콩불\n                                    (홍대점)
# 17185                                               노사이드
#
#                          location  estimation  viewCount  reviewCount  \
# 0      서울시 강남구 신사동 557-25 끌레르빌 1F         4.8   526248.0        131.0
# 1           서울시 강남구 신사동 518-15 B1         4.8    37905.0         48.0
# 2            서울시 강남구 신사동 525-2 1F         4.7    63134.0         91.0
# 3            서울시 강남구 신사동 525-9 1F         4.7   173210.0         86.0
# 4            서울시 강남구 신사동 539 대화빌딩         4.6   463574.0        133.0
# ...                           ...         ...        ...          ...
# 17181       서울시 마포구 연남동 229-56 1F         2.9     2388.0          9.0
# 17182          서울시 마포구 연남동 228-64         2.8     3882.0         22.0
# 17183           서울시 마포구 서교동 358-8         2.7    22083.0         29.0
# 17184           서울시 마포구 서교동 345-1         2.7     9264.0         35.0
# 17185          서울시 마포구 동교동 177-23         2.7   155561.0         68.0
#
#               foodType    price                                runTime
# 0       이자카야 / 오뎅 / 꼬치  3만원-4만원                          18:00 - 01:00
# 1                까스 요리   만원-2만원                          11:30 - 21:00
# 2      브런치 / 버거 / 샌드위치   만원-2만원                          11:30 - 22:00
# 3             카페 / 디저트   만원-2만원                          12:30 - 19:30
# 4       이자카야 / 오뎅 / 꼬치  2만원-3만원  월-목: 17:30 - 01:00 금-토: 17:30 - 02:00
# ...                ...      ...                                    ...
# 17181            퓨전 양식   만원-2만원                                   None
# 17182           회 / 스시   만원-2만원                          11:00 - 02:00
# 17183               뷔페   만원-2만원                          11:00 - 22:00
# 17184            고기 요리    만원 미만  월-목: 10:30 - 24:00 금-토: 10:30 - 01:00
# 17185            철판 요리   만원-2만원                                   None
#
# [17186 rows x 8 columns]

# %%
rawMangoData = mangoData.copy(deep=True)

# %%
mangoData = mangoData.drop_duplicates(subset='title', keep='first')

# %%
mangoData
# Out:
#                                                    title  \
# 0                                                    미라이
# 1                                                   상진식감
# 2       패티앤베지스\n                                    (신사)
# 3                                                    삐아프
# 4                                              와라야키 쿠이신보
# ...                                                  ...
# 17179                                               교수곱창
# 17180    랑데자뷰\n                                    (홍대점)
# 17183  스시오블랙컨테이너\n                                   ...
# 17184      콩불\n                                    (홍대점)
# 17185                                               노사이드
#
#                          location  estimation  viewCount  reviewCount  \
# 0      서울시 강남구 신사동 557-25 끌레르빌 1F         4.8   526248.0        131.0
# 1           서울시 강남구 신사동 518-15 B1         4.8    37905.0         48.0
# 2            서울시 강남구 신사동 525-2 1F         4.7    63134.0         91.0
# 3            서울시 강남구 신사동 525-9 1F         4.7   173210.0         86.0
# 4            서울시 강남구 신사동 539 대화빌딩         4.6   463574.0        133.0
# ...                           ...         ...        ...          ...
# 17179           서울시 마포구 서교동 357-1         2.9    12333.0         63.0
# 17180        서울시 마포구 서교동 339-5 B1         2.9     8361.0          7.0
# 17183           서울시 마포구 서교동 358-8         2.7    22083.0         29.0
# 17184           서울시 마포구 서교동 345-1         2.7     9264.0         35.0
# 17185          서울시 마포구 동교동 177-23         2.7   155561.0         68.0
#
#               foodType    price                                runTime
# 0       이자카야 / 오뎅 / 꼬치  3만원-4만원                          18:00 - 01:00
# 1                까스 요리   만원-2만원                          11:30 - 21:00
# 2      브런치 / 버거 / 샌드위치   만원-2만원                          11:30 - 22:00
# 3             카페 / 디저트   만원-2만원                          12:30 - 19:30
# 4       이자카야 / 오뎅 / 꼬치  2만원-3만원  월-목: 17:30 - 01:00 금-토: 17:30 - 02:00
# ...                ...      ...                                    ...
# 17179            고기 요리   만원-2만원                          16:00 - 07:00
# 17180         카페 / 디저트    만원 미만                          12:00 - 23:00
# 17183               뷔페   만원-2만원                          11:00 - 22:00
# 17184            고기 요리    만원 미만  월-목: 10:30 - 24:00 금-토: 10:30 - 01:00
# 17185            철판 요리   만원-2만원                                   None
#
# [9003 rows x 8 columns]

# %%
rawMangoData
# Out:
#                                                    title  \
# 0                                                    미라이
# 1                                                   상진식감
# 2       패티앤베지스\n                                    (신사)
# 3                                                    삐아프
# 4                                              와라야키 쿠이신보
# ...                                                  ...
# 17181   빠레뜨한남\n                                    (연남점)
# 17182   박용석스시\n                                    (연남점)
# 17183  스시오블랙컨테이너\n                                   ...
# 17184      콩불\n                                    (홍대점)
# 17185                                               노사이드
#
#                          location  estimation  viewCount  reviewCount  \
# 0      서울시 강남구 신사동 557-25 끌레르빌 1F         4.8   526248.0        131.0
# 1           서울시 강남구 신사동 518-15 B1         4.8    37905.0         48.0
# 2            서울시 강남구 신사동 525-2 1F         4.7    63134.0         91.0
# 3            서울시 강남구 신사동 525-9 1F         4.7   173210.0         86.0
# 4            서울시 강남구 신사동 539 대화빌딩         4.6   463574.0        133.0
# ...                           ...         ...        ...          ...
# 17181       서울시 마포구 연남동 229-56 1F         2.9     2388.0          9.0
# 17182          서울시 마포구 연남동 228-64         2.8     3882.0         22.0
# 17183           서울시 마포구 서교동 358-8         2.7    22083.0         29.0
# 17184           서울시 마포구 서교동 345-1         2.7     9264.0         35.0
# 17185          서울시 마포구 동교동 177-23         2.7   155561.0         68.0
#
#               foodType    price                                runTime
# 0       이자카야 / 오뎅 / 꼬치  3만원-4만원                          18:00 - 01:00
# 1                까스 요리   만원-2만원                          11:30 - 21:00
# 2      브런치 / 버거 / 샌드위치   만원-2만원                          11:30 - 22:00
# 3             카페 / 디저트   만원-2만원                          12:30 - 19:30
# 4       이자카야 / 오뎅 / 꼬치  2만원-3만원  월-목: 17:30 - 01:00 금-토: 17:30 - 02:00
# ...                ...      ...                                    ...
# 17181            퓨전 양식   만원-2만원                                   None
# 17182           회 / 스시   만원-2만원                          11:00 - 02:00
# 17183               뷔페   만원-2만원                          11:00 - 22:00
# 17184            고기 요리    만원 미만  월-목: 10:30 - 24:00 금-토: 10:30 - 01:00
# 17185            철판 요리   만원-2만원                                   None
#
# [17186 rows x 8 columns]

# %%
mangoData.to_csv('mangoData.csv', index=False, encoding='utf-8')

# %%
geoData = pd.read_excel("geoData.xlsx")
geoData = geoData[geoData["시도"] == "서울특별시"]
geoData = geoData.drop_duplicates(subset = ["시군구", "읍면동"])
geoData["geo"] = geoData["시도"] + " " + geoData["시군구"] + " " + geoData["읍면동"]
geoData
# Out:
#               코드     시도  시군구    읍면동   하위         위도          경도 코드종류  \
# 0     1111051500  서울특별시  종로구  청운효자동  NaN  37.584009  126.970626    H
# 1     1111053000  서울특별시  종로구    사직동  NaN  37.575408  126.965944    H
# 2     1111054000  서울특별시  종로구    삼청동  NaN  37.590758  126.980996    H
# 3     1111055000  서울특별시  종로구    부암동  NaN  37.594768  126.965574    H
# 4     1111056000  서울특별시  종로구    평창동  NaN  37.613029  126.974485    H
# ...          ...    ...  ...    ...  ...        ...         ...  ...
# 4005  1174010200  서울특별시  강동구    고덕동  NaN  37.561068  127.160582    B
# 4008  1174010600  서울특별시  강동구    둔촌동  NaN  37.531157  127.142891    B
# 4009  1174010700  서울특별시  강동구    암사동  NaN  37.552497  127.133010    B
# 4010  1174010800  서울특별시  강동구    성내동  NaN  37.531338  127.129174    B
# 4011  1174010900  서울특별시  강동구    천호동  NaN  37.543676  127.131748    B
#
#                   geo
# 0     서울특별시 종로구 청운효자동
# 1       서울특별시 종로구 사직동
# 2       서울특별시 종로구 삼청동
# 3       서울특별시 종로구 부암동
# 4       서울특별시 종로구 평창동
# ...               ...
# 4005    서울특별시 강동구 고덕동
# 4008    서울특별시 강동구 둔촌동
# 4009    서울특별시 강동구 암사동
# 4010    서울특별시 강동구 성내동
# 4011    서울특별시 강동구 천호동
#
# [806 rows x 9 columns]

# %%
mapData = pd.read_csv("mangoData.csv")
mapData["geo_1"] = "서울특별시"
mapData["geo_2"] = mapData["location"].str.split(" ").str[1]
mapData["geo_3"] = mapData["location"].str.split(" ").str[2]
mapData["geo"] = mapData["geo_1"] + " " + mapData["geo_2"] + " " + mapData["geo_3"]

mapData = pd.merge(left = mapData, right = geoData[["위도", "경도", "geo"]], how = "left", left_on = "geo", right_on = "geo")
mapData = mapData.dropna(subset = ["위도","경도"]).reset_index(drop=True)
mapData
# Out:
#                                                   title  \
# 0                                                   미라이
# 1                                                  상진식감
# 2      패티앤베지스\n                                    (신사)
# 3                                                   삐아프
# 4                                             와라야키 쿠이신보
# ...                                                 ...
# 8723                                               교수곱창
# 8724    랑데자뷰\n                                    (홍대점)
# 8725  스시오블랙컨테이너\n                                   ...
# 8726      콩불\n                                    (홍대점)
# 8727                                               노사이드
#
#                         location  estimation  viewCount  reviewCount  \
# 0     서울시 강남구 신사동 557-25 끌레르빌 1F         4.8   526248.0        131.0
# 1          서울시 강남구 신사동 518-15 B1         4.8    37905.0         48.0
# 2           서울시 강남구 신사동 525-2 1F         4.7    63134.0         91.0
# 3           서울시 강남구 신사동 525-9 1F         4.7   173210.0         86.0
# 4           서울시 강남구 신사동 539 대화빌딩         4.6   463574.0        133.0
# ...                          ...         ...        ...          ...
# 8723           서울시 마포구 서교동 357-1         2.9    12333.0         63.0
# 8724        서울시 마포구 서교동 339-5 B1         2.9     8361.0          7.0
# 8725           서울시 마포구 서교동 358-8         2.7    22083.0         29.0
# 8726           서울시 마포구 서교동 345-1         2.7     9264.0         35.0
# 8727          서울시 마포구 동교동 177-23         2.7   155561.0         68.0
#
#              foodType    price                                runTime  geo_1  \
# 0      이자카야 / 오뎅 / 꼬치  3만원-4만원                          18:00 - 01:00  서울특별시
# 1               까스 요리   만원-2만원                          11:30 - 21:00  서울특별시
# 2     브런치 / 버거 / 샌드위치   만원-2만원                          11:30 - 22:00  서울특별시
# 3            카페 / 디저트   만원-2만원                          12:30 - 19:30  서울특별시
# 4      이자카야 / 오뎅 / 꼬치  2만원-3만원  월-목: 17:30 - 01:00 금-토: 17:30 - 02:00  서울특별시
# ...               ...      ...                                    ...    ...
# 8723            고기 요리   만원-2만원                          16:00 - 07:00  서울특별시
# 8724         카페 / 디저트    만원 미만                          12:00 - 23:00  서울특별시
# 8725               뷔페   만원-2만원                          11:00 - 22:00  서울특별시
# 8726            고기 요리    만원 미만  월-목: 10:30 - 24:00 금-토: 10:30 - 01:00  서울특별시
# 8727            철판 요리   만원-2만원                                    NaN  서울특별시
#
#      geo_2 geo_3            geo         위도          경도
# 0      강남구   신사동  서울특별시 강남구 신사동  37.523807  127.026492
# 1      강남구   신사동  서울특별시 강남구 신사동  37.523807  127.026492
# 2      강남구   신사동  서울특별시 강남구 신사동  37.523807  127.026492
# 3      강남구   신사동  서울특별시 강남구 신사동  37.523807  127.026492
# 4      강남구   신사동  서울특별시 강남구 신사동  37.523807  127.026492
# ...    ...   ...            ...        ...         ...
# 8723   마포구   서교동  서울특별시 마포구 서교동  37.553838  126.918765
# 8724   마포구   서교동  서울특별시 마포구 서교동  37.553838  126.918765
# 8725   마포구   서교동  서울특별시 마포구 서교동  37.553838  126.918765
# 8726   마포구   서교동  서울특별시 마포구 서교동  37.553838  126.918765
# 8727   마포구   동교동  서울특별시 마포구 동교동  37.557650  126.925663
#
# [8728 rows x 14 columns]

# %%
mapData.to_csv('mangoMapData.csv', index=False, encoding='utf-8')
